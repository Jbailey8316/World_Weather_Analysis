# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(10)
# Out:
#    Unnamed: 0          City Country  Max Temp Current Description      Lat  \
# 0           0        Kijang      KR     60.80       broken clouds  35.2442
# 1           1    Kaitangata      NZ     64.00       moderate rain -46.2817
# 2           2   New Norfolk      AU     64.00       broken clouds -42.7826
# 3          12         Bluff      NZ     62.01          light rain -46.6000
# 4          22         Pisco      PE     68.00           clear sky -13.7000
# 5          26        Castro      BR     64.29          light rain -24.7911
# 6          27     El Dorado      US     66.00           clear sky  38.7666
# 7          37   Port Alfred      ZA     61.34          light rain -33.5906
# 8          46    Nouadhibou      MR     64.40           clear sky  20.9310
# 9          56  Ponta Do Sol      PT     64.40       broken clouds  32.6667
#
#         Lng                                     Hotel Name
# 0  129.2139                            Samyang Beach Villa
# 1  169.8464                          Kaitangata Motor Camp
# 2  147.0587                The Shingles Riverside Cottages
# 3  168.3333  Bluff Homestead - Guesthouse & Campervan Park
# 4  -76.2167                       Hotel San Isidro Oficial
# 5  -50.0119                                 CHACARA BAILLY
# 6 -120.5177                         Bridal Veil Campground
# 7   26.8910                             The Halyards Hotel
# 8  -17.0347                                      El Medina
# 9  -17.1000                                 Hotel do Campo

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Use dataframe display to help search for usable cities/hotels
brazil_df = vacation_df.loc[(vacation_df["Country"] == "BR")]
brazil_df.dropna()
# Out:
#      Unnamed: 0                      City Country  Max Temp  \
# 40          161           Arraial Do Cabo      BR     77.49
# 61          232  Sao Jose Da Coroa Grande      BR     76.05
# 71          268                    Touros      BR     77.00
# 87          329                Diamantino      BR     75.06
# 93          347                    Olinda      BR     75.20
# 111         388             Florianopolis      BR     75.20
# 114         399                Vila Velha      BR     77.00
# 128         435               Porto Velho      BR     77.00
# 134         446                    Maceio      BR     75.20
# 146         491                  Belmonte      BR     77.00
# 148         499               Altinopolis      BR     77.00
# 155         524                 Itamaraca      BR     75.20
# 160         543                     Macae      BR     77.00
# 163         548                     Conde      BR     77.00
# 169         568                  Cabedelo      BR     77.00
# 182         612                 Piacabucu      BR     76.82
# 186         622                  Maragogi      BR     75.79
#
#     Current Description      Lat      Lng  \
# 40            clear sky -22.9661 -42.0278
# 61        broken clouds  -8.8978 -35.1478
# 71     scattered clouds  -5.1989 -35.4608
# 87        broken clouds -14.4086 -56.4461
# 93                 mist  -8.0089 -34.8553
# 111       broken clouds -27.6146 -48.5012
# 114           clear sky -20.3297 -40.2925
# 128          light rain  -8.7619 -63.9039
# 134                mist  -9.6658 -35.7353
# 146           clear sky -15.8631 -38.8828
# 148           clear sky -21.0256 -47.3739
# 155                mist  -7.7478 -34.8256
# 160           clear sky -22.3708 -41.7869
# 163          light rain  -7.2597 -34.9075
# 169       broken clouds  -6.9811 -34.8339
# 182       broken clouds -10.4056 -36.4344
# 186     overcast clouds  -9.0122 -35.2225
#
#                                    Hotel Name
# 40                        Pousada Porto Praia
# 61                           Crôa Mares Hotel
# 71                            INN NEW HORIZON
# 87                                Hotel Delta
# 93                   Hotel Albergue de Olinda
# 111        Hotel Boutique Quinta das Videiras
# 114                 Quality Suites Vila Velha
# 128                             Hotel Central
# 134                            Poutur Pousada
# 146               Pousada Monte Carmelo O Pão
# 148                  Hotel Vila das Palmeiras
# 155               Special K's Bed & Breakfast
# 160                            Personal Hotel
# 163                        Pousada Beija Flor
# 169                             Hotel Pigalle
# 182                            Piaçabuçu News
# 186  Salinas do Maragogi All Inclusive Resort

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
vacation_start = vacation_df.loc[(vacation_df["City"] == "Olinda")]
vacation_stop1 = vacation_df.loc[(vacation_df["City"] == "Itamaraca")]
vacation_stop2 = vacation_df.loc[(vacation_df["City"] == "Conde")]
vacation_stop3 = vacation_df.loc[(vacation_df["City"] == "Cabedelo")] 
vacation_end = vacation_df.loc[(vacation_df["City"] == "Olinda")]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
print(f'Start: {start}, End: {end}')

# Get the lat and lng for the stops
coords_stop_1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
coords_stop_2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
coords_stop_3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]
print(f'Stop 1: {coords_stop_1}, Stop 2: {coords_stop_2}, Stop 3: {coords_stop_3}')
# Out:
# Start: (-8.0089, -34.8553), End: (-8.0089, -34.8553)
# Stop 1: (-7.7478, -34.8256), Stop 2: (-7.2597, -34.9075), Stop 3: (-6.9811, -34.8339)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

#Driving Directions
import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)

fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
        start, end, waypoints=[coords_stop_1, coords_stop_2, coords_stop_3],
        travel_mode = "DRIVING")

fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
combined_cities = [vacation_start, vacation_stop1, vacation_stop2, vacation_stop3]

four_cities_df = pd.concat(combined_cities, sort=False)
four_cities_df
# Out:
#      Unnamed: 0       City Country  Max Temp Current Description     Lat  \
# 93          347     Olinda      BR      75.2                mist -8.0089
# 155         524  Itamaraca      BR      75.2                mist -7.7478
# 163         548      Conde      BR      77.0          light rain -7.2597
# 169         568   Cabedelo      BR      77.0       broken clouds -6.9811
#
#          Lng                   Hotel Name
# 93  -34.8553     Hotel Albergue de Olinda
# 155 -34.8256  Special K's Bed & Breakfast
# 163 -34.9075           Pousada Beija Flor
# 169 -34.8339                Hotel Pigalle

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in four_cities_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = four_cities_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
max_temp = four_cities_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
