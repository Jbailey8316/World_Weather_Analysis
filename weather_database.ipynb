# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kijang
# Processing Record 2 of Set 1 | kaitangata
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | novi ligure
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 1 | bilibino
# Processing Record 11 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 1 | redmond
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | luderitz
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | fairbanks
# Processing Record 19 of Set 1 | ballyshannon
# Processing Record 20 of Set 1 | la libertad
# Processing Record 21 of Set 1 | kismayo
# Processing Record 22 of Set 1 | khorixas
# Processing Record 23 of Set 1 | karratha
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | alofi
# Processing Record 27 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 1 | pisco
# Processing Record 29 of Set 1 | marsa matruh
# Processing Record 30 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 1 | japura
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | el dorado
# Processing Record 35 of Set 1 | jacqueville
# Processing Record 36 of Set 1 | kamenka
# Processing Record 37 of Set 1 | ixtapa
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | aklavik
# Processing Record 40 of Set 1 | champerico
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | baykit
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | rawlins
# Processing Record 48 of Set 1 | nanortalik
# Processing Record 49 of Set 1 | college
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | nichlaul
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | kropotkin
# Processing Record 4 of Set 2 | nouadhibou
# Processing Record 5 of Set 2 | acari
# Processing Record 6 of Set 2 | benjamin hill
# Processing Record 7 of Set 2 | kodiak
# Processing Record 8 of Set 2 | saryg-sep
# Processing Record 9 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | gushikawa
# Processing Record 12 of Set 2 | korla
# Processing Record 13 of Set 2 | bethpage
# Processing Record 14 of Set 2 | chum phae
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | mangan
# Processing Record 17 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | vallenar
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | general pico
# Processing Record 24 of Set 2 | tahta
# Processing Record 25 of Set 2 | lavrentiya
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | lensk
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | kaduqli
# Processing Record 31 of Set 2 | cherskiy
# Processing Record 32 of Set 2 | hvammstangi
# City not found. Skipping...
# Processing Record 33 of Set 2 | padang
# Processing Record 34 of Set 2 | am timan
# Processing Record 35 of Set 2 | kayerkan
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | goderich
# Processing Record 39 of Set 2 | coolum beach
# Processing Record 40 of Set 2 | lompoc
# Processing Record 41 of Set 2 | castleisland
# Processing Record 42 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 43 of Set 2 | mantua
# Processing Record 44 of Set 2 | matagami
# Processing Record 45 of Set 2 | duxbury
# Processing Record 46 of Set 2 | lagoa
# Processing Record 47 of Set 2 | nemuro
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | tungor
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | batagay
# Processing Record 2 of Set 3 | mataura
# Processing Record 3 of Set 3 | monster
# Processing Record 4 of Set 3 | judenburg
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | guymon
# Processing Record 7 of Set 3 | horta
# Processing Record 8 of Set 3 | sakakah
# Processing Record 9 of Set 3 | anloga
# Processing Record 10 of Set 3 | tromso
# Processing Record 11 of Set 3 | safwah
# City not found. Skipping...
# Processing Record 12 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | kirensk
# Processing Record 15 of Set 3 | sturgis
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | asfi
# Processing Record 18 of Set 3 | punta arenas
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | huarmey
# Processing Record 21 of Set 3 | puerto carreno
# Processing Record 22 of Set 3 | katsuura
# Processing Record 23 of Set 3 | ostrovnoy
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 3 | port-gentil
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | sobolevo
# Processing Record 30 of Set 3 | uaua
# Processing Record 31 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 3 | amahai
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | necochea
# Processing Record 37 of Set 3 | coihaique
# Processing Record 38 of Set 3 | high level
# Processing Record 39 of Set 3 | tura
# Processing Record 40 of Set 3 | kalaleh
# Processing Record 41 of Set 3 | bukama
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | okhotsk
# Processing Record 44 of Set 3 | amapa
# Processing Record 45 of Set 3 | upernavik
# Processing Record 46 of Set 3 | payo
# Processing Record 47 of Set 3 | flinders
# Processing Record 48 of Set 3 | east london
# Processing Record 49 of Set 3 | kwinana
# Processing Record 50 of Set 3 | pierre
# Processing Record 1 of Set 4 | buala
# Processing Record 2 of Set 4 | sumenep
# Processing Record 3 of Set 4 | dunyapur
# Processing Record 4 of Set 4 | floro
# Processing Record 5 of Set 4 | severo-kurilsk
# Processing Record 6 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 4 | pangnirtung
# Processing Record 8 of Set 4 | ocampo
# Processing Record 9 of Set 4 | ancud
# Processing Record 10 of Set 4 | freeport
# Processing Record 11 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | beyneu
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | cayenne
# Processing Record 16 of Set 4 | port elizabeth
# Processing Record 17 of Set 4 | siparia
# Processing Record 18 of Set 4 | arona
# Processing Record 19 of Set 4 | blackwater
# Processing Record 20 of Set 4 | praia da vitoria
# Processing Record 21 of Set 4 | whyalla
# Processing Record 22 of Set 4 | henties bay
# Processing Record 23 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 4 | airai
# Processing Record 25 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 26 of Set 4 | esperance
# Processing Record 27 of Set 4 | hamilton
# Processing Record 28 of Set 4 | guaraniacu
# Processing Record 29 of Set 4 | krivopolyanye
# City not found. Skipping...
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | geraldton
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | staroaleyskoye
# Processing Record 34 of Set 4 | khatanga
# Processing Record 35 of Set 4 | zhezkazgan
# Processing Record 36 of Set 4 | clonakilty
# Processing Record 37 of Set 4 | santa rosa de aguan
# Processing Record 38 of Set 4 | abiy adi
# City not found. Skipping...
# Processing Record 39 of Set 4 | latung
# Processing Record 40 of Set 4 | santa cruz
# Processing Record 41 of Set 4 | mandiana
# Processing Record 42 of Set 4 | zaymishche
# Processing Record 43 of Set 4 | praia
# Processing Record 44 of Set 4 | vao
# Processing Record 45 of Set 4 | kulhudhuffushi
# Processing Record 46 of Set 4 | port-cartier
# Processing Record 47 of Set 4 | whitehorse
# Processing Record 48 of Set 4 | chuy
# Processing Record 49 of Set 4 | gat
# Processing Record 50 of Set 4 | port augusta
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 2 of Set 5 | tucurui
# Processing Record 3 of Set 5 | baruun-urt
# Processing Record 4 of Set 5 | tiruchchendur
# Processing Record 5 of Set 5 | san quintin
# Processing Record 6 of Set 5 | abha
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | bacoli
# Processing Record 9 of Set 5 | kashi
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 5 | sibolga
# Processing Record 13 of Set 5 | puri
# Processing Record 14 of Set 5 | kinablangan
# Processing Record 15 of Set 5 | zyryanka
# Processing Record 16 of Set 5 | yellowknife
# Processing Record 17 of Set 5 | bandarbeyla
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | wahpeton
# Processing Record 20 of Set 5 | hambantota
# Processing Record 21 of Set 5 | saint-pierre
# Processing Record 22 of Set 5 | beringovskiy
# Processing Record 23 of Set 5 | narsaq
# Processing Record 24 of Set 5 | viedma
# Processing Record 25 of Set 5 | marzuq
# Processing Record 26 of Set 5 | ambovombe
# Processing Record 27 of Set 5 | perth
# Processing Record 28 of Set 5 | port blair
# Processing Record 29 of Set 5 | nioki
# Processing Record 30 of Set 5 | sinnamary
# Processing Record 31 of Set 5 | manali
# Processing Record 32 of Set 5 | fukue
# Processing Record 33 of Set 5 | nador
# Processing Record 34 of Set 5 | siguiri
# Processing Record 35 of Set 5 | naze
# Processing Record 36 of Set 5 | buraydah
# Processing Record 37 of Set 5 | kamaishi
# Processing Record 38 of Set 5 | oga
# Processing Record 39 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 5 | hasaki
# Processing Record 41 of Set 5 | biak
# Processing Record 42 of Set 5 | koumac
# Processing Record 43 of Set 5 | malakal
# Processing Record 44 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 47 of Set 5 | djibo
# Processing Record 48 of Set 5 | umm kaddadah
# Processing Record 49 of Set 5 | fare
# Processing Record 50 of Set 5 | chimbote
# Processing Record 1 of Set 6 | luorong
# Processing Record 2 of Set 6 | kurali
# Processing Record 3 of Set 6 | turtkul
# City not found. Skipping...
# Processing Record 4 of Set 6 | aitape
# Processing Record 5 of Set 6 | coquimbo
# Processing Record 6 of Set 6 | wadena
# Processing Record 7 of Set 6 | bozeman
# Processing Record 8 of Set 6 | balkanabat
# Processing Record 9 of Set 6 | port hedland
# Processing Record 10 of Set 6 | sao jose da coroa grande
# Processing Record 11 of Set 6 | dongsheng
# Processing Record 12 of Set 6 | shibetsu
# Processing Record 13 of Set 6 | moose factory
# Processing Record 14 of Set 6 | samarai
# Processing Record 15 of Set 6 | trinidad
# Processing Record 16 of Set 6 | praya
# Processing Record 17 of Set 6 | tomatlan
# Processing Record 18 of Set 6 | georgetown
# Processing Record 19 of Set 6 | evensk
# Processing Record 20 of Set 6 | tyret pervaya
# Processing Record 21 of Set 6 | weihai
# Processing Record 22 of Set 6 | awjilah
# Processing Record 23 of Set 6 | dhidhdhoo
# Processing Record 24 of Set 6 | prainha
# Processing Record 25 of Set 6 | andenes
# Processing Record 26 of Set 6 | muisne
# Processing Record 27 of Set 6 | shubarkuduk
# Processing Record 28 of Set 6 | luangwa
# Processing Record 29 of Set 6 | yulara
# Processing Record 30 of Set 6 | balikpapan
# Processing Record 31 of Set 6 | berlevag
# Processing Record 32 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 6 | san patricio
# Processing Record 34 of Set 6 | xiangfan
# Processing Record 35 of Set 6 | smithers
# Processing Record 36 of Set 6 | shenjiamen
# Processing Record 37 of Set 6 | lebu
# Processing Record 38 of Set 6 | carora
# Processing Record 39 of Set 6 | sompeta
# Processing Record 40 of Set 6 | holme
# Processing Record 41 of Set 6 | lasa
# Processing Record 42 of Set 6 | ossora
# Processing Record 43 of Set 6 | kitami
# Processing Record 44 of Set 6 | baracoa
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | lianzhou
# Processing Record 47 of Set 6 | touros
# Processing Record 48 of Set 6 | tokur
# Processing Record 49 of Set 6 | yantzaza
# Processing Record 50 of Set 6 | quatre cocos
# Processing Record 1 of Set 7 | la ronge
# Processing Record 2 of Set 7 | esna
# Processing Record 3 of Set 7 | carutapera
# Processing Record 4 of Set 7 | victoria
# Processing Record 5 of Set 7 | gorom-gorom
# Processing Record 6 of Set 7 | dipkarpaz
# City not found. Skipping...
# Processing Record 7 of Set 7 | suntar
# Processing Record 8 of Set 7 | iqaluit
# Processing Record 9 of Set 7 | kaeo
# Processing Record 10 of Set 7 | jeremoabo
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | hammerfest
# Processing Record 13 of Set 7 | nova olinda do norte
# Processing Record 14 of Set 7 | egvekinot
# Processing Record 15 of Set 7 | laguna
# Processing Record 16 of Set 7 | shelburne
# Processing Record 17 of Set 7 | coromoro
# Processing Record 18 of Set 7 | sao felix do xingu
# Processing Record 19 of Set 7 | istria
# Processing Record 20 of Set 7 | barrow
# Processing Record 21 of Set 7 | yar-sale
# Processing Record 22 of Set 7 | fortuna
# Processing Record 23 of Set 7 | mersing
# Processing Record 24 of Set 7 | dubbo
# Processing Record 25 of Set 7 | road town
# Processing Record 26 of Set 7 | talnakh
# Processing Record 27 of Set 7 | kuching
# Processing Record 28 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 29 of Set 7 | nikolskoye
# Processing Record 30 of Set 7 | estelle
# Processing Record 31 of Set 7 | calabozo
# Processing Record 32 of Set 7 | shirokiy
# Processing Record 33 of Set 7 | san juan
# Processing Record 34 of Set 7 | tommot
# Processing Record 35 of Set 7 | corinto
# Processing Record 36 of Set 7 | yarada
# Processing Record 37 of Set 7 | karoti
# Processing Record 38 of Set 7 | vigrestad
# Processing Record 39 of Set 7 | casian
# Processing Record 40 of Set 7 | brazzaville
# Processing Record 41 of Set 7 | alta floresta
# Processing Record 42 of Set 7 | krasnogvardeyets
# Processing Record 43 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 7 | aksarka
# Processing Record 45 of Set 7 | savannah bight
# Processing Record 46 of Set 7 | sharjah
# Processing Record 47 of Set 7 | kuusamo
# Processing Record 48 of Set 7 | provideniya
# Processing Record 49 of Set 7 | bandundu
# Processing Record 50 of Set 7 | domodossola
# Processing Record 1 of Set 8 | mehamn
# Processing Record 2 of Set 8 | norman wells
# Processing Record 3 of Set 8 | balti
# Processing Record 4 of Set 8 | richards bay
# Processing Record 5 of Set 8 | kotma
# Processing Record 6 of Set 8 | morant bay
# Processing Record 7 of Set 8 | lodja
# Processing Record 8 of Set 8 | powell river
# Processing Record 9 of Set 8 | lata
# Processing Record 10 of Set 8 | mana
# Processing Record 11 of Set 8 | diamantino
# Processing Record 12 of Set 8 | kitob
# Processing Record 13 of Set 8 | olavarria
# Processing Record 14 of Set 8 | koshurnikovo
# Processing Record 15 of Set 8 | bethel
# Processing Record 16 of Set 8 | cap malheureux
# Processing Record 17 of Set 8 | guadalupe y calvo
# Processing Record 18 of Set 8 | port moresby
# Processing Record 19 of Set 8 | guerrero negro
# Processing Record 20 of Set 8 | tamale
# Processing Record 21 of Set 8 | majagual
# Processing Record 22 of Set 8 | kavieng
# Processing Record 23 of Set 8 | mahebourg
# Processing Record 24 of Set 8 | maniitsoq
# Processing Record 25 of Set 8 | mayya
# Processing Record 26 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 27 of Set 8 | te anau
# Processing Record 28 of Set 8 | faro
# Processing Record 29 of Set 8 | yandoon
# City not found. Skipping...
# Processing Record 30 of Set 8 | tuatapere
# Processing Record 31 of Set 8 | olinda
# Processing Record 32 of Set 8 | hami
# Processing Record 33 of Set 8 | mareeba
# Processing Record 34 of Set 8 | marawi
# Processing Record 35 of Set 8 | itoman
# Processing Record 36 of Set 8 | vostok
# Processing Record 37 of Set 8 | laem sing
# Processing Record 38 of Set 8 | warrington
# Processing Record 39 of Set 8 | quelimane
# Processing Record 40 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 8 | uzhur-4
# City not found. Skipping...
# Processing Record 42 of Set 8 | viru
# Processing Record 43 of Set 8 | faanui
# Processing Record 44 of Set 8 | mamou
# Processing Record 45 of Set 8 | sorong
# Processing Record 46 of Set 8 | mastic beach
# Processing Record 47 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 8 | aneho
# Processing Record 49 of Set 8 | maniago
# Processing Record 50 of Set 8 | barra patuca
# Processing Record 1 of Set 9 | miraflores
# Processing Record 2 of Set 9 | neiafu
# Processing Record 3 of Set 9 | newcastle
# Processing Record 4 of Set 9 | carballo
# Processing Record 5 of Set 9 | abulug
# Processing Record 6 of Set 9 | frederick
# Processing Record 7 of Set 9 | tocopilla
# Processing Record 8 of Set 9 | sokoni
# Processing Record 9 of Set 9 | mananjary
# Processing Record 10 of Set 9 | someshwar
# Processing Record 11 of Set 9 | ulkan
# Processing Record 12 of Set 9 | lorengau
# Processing Record 13 of Set 9 | mohlin
# Processing Record 14 of Set 9 | katubao
# Processing Record 15 of Set 9 | nikel
# Processing Record 16 of Set 9 | puerto escondido
# Processing Record 17 of Set 9 | kenai
# Processing Record 18 of Set 9 | moron
# Processing Record 19 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 9 | aksay
# Processing Record 21 of Set 9 | tazovskiy
# Processing Record 22 of Set 9 | zhaotong
# Processing Record 23 of Set 9 | asau
# Processing Record 24 of Set 9 | san policarpo
# Processing Record 25 of Set 9 | poso
# Processing Record 26 of Set 9 | florianopolis
# Processing Record 27 of Set 9 | sao jose do calcado
# Processing Record 28 of Set 9 | ruwi
# Processing Record 29 of Set 9 | betanzos
# Processing Record 30 of Set 9 | atambua
# Processing Record 31 of Set 9 | ketchikan
# Processing Record 32 of Set 9 | vardo
# Processing Record 33 of Set 9 | toungoo
# City not found. Skipping...
# Processing Record 34 of Set 9 | poole
# Processing Record 35 of Set 9 | miguel calmon
# Processing Record 36 of Set 9 | sorland
# Processing Record 37 of Set 9 | belaya gora
# Processing Record 38 of Set 9 | vila velha
# Processing Record 39 of Set 9 | san ramon
# Processing Record 40 of Set 9 | alice springs
# Processing Record 41 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 9 | portland
# Processing Record 43 of Set 9 | santa fe
# Processing Record 44 of Set 9 | cradock
# Processing Record 45 of Set 9 | aripuana
# Processing Record 46 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 9 | swidnica
# Processing Record 48 of Set 9 | uvira
# Processing Record 49 of Set 9 | bischwiller
# Processing Record 50 of Set 9 | straumen
# Processing Record 1 of Set 10 | mehran
# Processing Record 2 of Set 10 | the valley
# Processing Record 3 of Set 10 | kauhajoki
# Processing Record 4 of Set 10 | kolondieba
# Processing Record 5 of Set 10 | thompson
# Processing Record 6 of Set 10 | san buenaventura
# Processing Record 7 of Set 10 | mackay
# Processing Record 8 of Set 10 | guanare
# Processing Record 9 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 10 | vestmannaeyjar
# Processing Record 11 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 12 of Set 10 | yenagoa
# Processing Record 13 of Set 10 | tubmanburg
# Processing Record 14 of Set 10 | labuhan
# Processing Record 15 of Set 10 | etampes
# Processing Record 16 of Set 10 | dunedin
# Processing Record 17 of Set 10 | sur
# Processing Record 18 of Set 10 | half moon bay
# Processing Record 19 of Set 10 | gari
# Processing Record 20 of Set 10 | rorvik
# Processing Record 21 of Set 10 | shache
# Processing Record 22 of Set 10 | bereda
# Processing Record 23 of Set 10 | marienburg
# Processing Record 24 of Set 10 | moose jaw
# Processing Record 25 of Set 10 | kalmunai
# Processing Record 26 of Set 10 | virginia beach
# Processing Record 27 of Set 10 | rock sound
# Processing Record 28 of Set 10 | porto velho
# Processing Record 29 of Set 10 | nuevo ideal
# Processing Record 30 of Set 10 | akyab
# Processing Record 31 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 33 of Set 10 | beloha
# Processing Record 34 of Set 10 | aykhal
# Processing Record 35 of Set 10 | arawa
# Processing Record 36 of Set 10 | si bun ruang
# Processing Record 37 of Set 10 | ati
# Processing Record 38 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 10 | honiara
# Processing Record 40 of Set 10 | kutum
# Processing Record 41 of Set 10 | sigli
# Processing Record 42 of Set 10 | maceio
# Processing Record 43 of Set 10 | imperial
# Processing Record 44 of Set 10 | nuuk
# Processing Record 45 of Set 10 | qaanaaq
# Processing Record 46 of Set 10 | port shepstone
# Processing Record 47 of Set 10 | zhicheng
# Processing Record 48 of Set 10 | arcachon
# Processing Record 49 of Set 10 | makakilo city
# Processing Record 50 of Set 10 | akdepe
# Processing Record 1 of Set 11 | bodden town
# Processing Record 2 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 3 of Set 11 | aguimes
# Processing Record 4 of Set 11 | caravelas
# Processing Record 5 of Set 11 | batemans bay
# Processing Record 6 of Set 11 | acapulco
# Processing Record 7 of Set 11 | mashhad
# Processing Record 8 of Set 11 | constitucion
# Processing Record 9 of Set 11 | pasni
# Processing Record 10 of Set 11 | flin flon
# Processing Record 11 of Set 11 | gannan
# Processing Record 12 of Set 11 | forest lake
# Processing Record 13 of Set 11 | muros
# Processing Record 14 of Set 11 | ocho rios
# Processing Record 15 of Set 11 | dingle
# Processing Record 16 of Set 11 | solnechnyy
# Processing Record 17 of Set 11 | eskil
# Processing Record 18 of Set 11 | filadelfia
# Processing Record 19 of Set 11 | yavoriv
# Processing Record 20 of Set 11 | barentu
# Processing Record 21 of Set 11 | najran
# Processing Record 22 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 11 | longhua
# Processing Record 24 of Set 11 | kapustin yar
# Processing Record 25 of Set 11 | mabaruma
# Processing Record 26 of Set 11 | povenets
# Processing Record 27 of Set 11 | mount gambier
# Processing Record 28 of Set 11 | kupang
# Processing Record 29 of Set 11 | nishihara
# Processing Record 30 of Set 11 | apen
# Processing Record 31 of Set 11 | galesong
# Processing Record 32 of Set 11 | chapais
# Processing Record 33 of Set 11 | husavik
# Processing Record 34 of Set 11 | namibe
# Processing Record 35 of Set 11 | toamasina
# Processing Record 36 of Set 11 | miracema do tocantins
# Processing Record 37 of Set 11 | noyabrsk
# Processing Record 38 of Set 11 | broome
# Processing Record 39 of Set 11 | belmonte
# Processing Record 40 of Set 11 | matara
# Processing Record 41 of Set 11 | aban
# Processing Record 42 of Set 11 | balagansk
# Processing Record 43 of Set 11 | borehamwood
# Processing Record 44 of Set 11 | calvinia
# Processing Record 45 of Set 11 | ahipara
# Processing Record 46 of Set 11 | mikkeli
# Processing Record 47 of Set 11 | duz
# City not found. Skipping...
# Processing Record 48 of Set 11 | altinopolis
# Processing Record 49 of Set 11 | harper
# Processing Record 50 of Set 11 | tual
# Processing Record 1 of Set 12 | alugan
# Processing Record 2 of Set 12 | sungaipenuh
# Processing Record 3 of Set 12 | molina
# Processing Record 4 of Set 12 | chumikan
# Processing Record 5 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 12 | medea
# Processing Record 7 of Set 12 | broken hill
# Processing Record 8 of Set 12 | filandia
# Processing Record 9 of Set 12 | dibombari
# Processing Record 10 of Set 12 | upata
# Processing Record 11 of Set 12 | methoni
# Processing Record 12 of Set 12 | vredendal
# Processing Record 13 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 12 | rawson
# Processing Record 15 of Set 12 | caraquet
# Processing Record 16 of Set 12 | kodinsk
# Processing Record 17 of Set 12 | kununurra
# Processing Record 18 of Set 12 | rio de oro
# Processing Record 19 of Set 12 | berbera
# Processing Record 20 of Set 12 | sabang
# Processing Record 21 of Set 12 | fot
# Processing Record 22 of Set 12 | umea
# Processing Record 23 of Set 12 | pishin
# Processing Record 24 of Set 12 | teguise
# Processing Record 25 of Set 12 | itamaraca
# Processing Record 26 of Set 12 | panzhihua
# Processing Record 27 of Set 12 | goteborg
# City not found. Skipping...
# Processing Record 28 of Set 12 | sitka
# Processing Record 29 of Set 12 | marystown
# Processing Record 30 of Set 12 | concarneau
# Processing Record 31 of Set 12 | denia
# Processing Record 32 of Set 12 | salalah
# Processing Record 33 of Set 12 | capreol
# Processing Record 34 of Set 12 | oksfjord
# Processing Record 35 of Set 12 | naryan-mar
# Processing Record 36 of Set 12 | kabo
# Processing Record 37 of Set 12 | longyan
# Processing Record 38 of Set 12 | tautira
# Processing Record 39 of Set 12 | paita
# Processing Record 40 of Set 12 | boshnyakovo
# Processing Record 41 of Set 12 | ojinaga
# Processing Record 42 of Set 12 | menongue
# Processing Record 43 of Set 12 | pimentel
# Processing Record 44 of Set 12 | roma
# Processing Record 45 of Set 12 | macae
# Processing Record 46 of Set 12 | rodeo
# Processing Record 47 of Set 12 | jacksonville
# Processing Record 48 of Set 12 | kurilsk
# Processing Record 49 of Set 12 | tetela de ocampo
# Processing Record 50 of Set 12 | conde
# Processing Record 1 of Set 13 | anadyr
# Processing Record 2 of Set 13 | keflavik
# Processing Record 3 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 4 of Set 13 | cuamba
# Processing Record 5 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 13 | nkowakowa
# Processing Record 7 of Set 13 | thurso
# Processing Record 8 of Set 13 | zasosna
# Processing Record 9 of Set 13 | izvestkovyy
# Processing Record 10 of Set 13 | robertsport
# Processing Record 11 of Set 13 | sinjar
# Processing Record 12 of Set 13 | cockburn town
# Processing Record 13 of Set 13 | diego de almagro
# Processing Record 14 of Set 13 | sozimskiy
# Processing Record 15 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 13 | bandar maharani
# City not found. Skipping...
# Processing Record 17 of Set 13 | patrocinio
# Processing Record 18 of Set 13 | atar
# Processing Record 19 of Set 13 | sijunjung
# Processing Record 20 of Set 13 | muleba
# Processing Record 21 of Set 13 | maneadero
# Processing Record 22 of Set 13 | dakar
# Processing Record 23 of Set 13 | dongli
# Processing Record 24 of Set 13 | cabedelo
# Processing Record 25 of Set 13 | palaiokhora
# City not found. Skipping...
# Processing Record 26 of Set 13 | meadow lake
# Processing Record 27 of Set 13 | puerto del rosario
# Processing Record 28 of Set 13 | la asuncion
# Processing Record 29 of Set 13 | san andres
# Processing Record 30 of Set 13 | khovu-aksy
# Processing Record 31 of Set 13 | bontang
# Processing Record 32 of Set 13 | urulga
# City not found. Skipping...
# Processing Record 33 of Set 13 | yichang
# Processing Record 34 of Set 13 | ponta delgada
# Processing Record 35 of Set 13 | ola
# Processing Record 36 of Set 13 | noumea
# Processing Record 37 of Set 13 | linda
# Processing Record 38 of Set 13 | wagar
# Processing Record 39 of Set 13 | kukushtan
# Processing Record 40 of Set 13 | kahului
# Processing Record 41 of Set 13 | kinsale
# Processing Record 42 of Set 13 | capitan meza
# Processing Record 43 of Set 13 | omsukchan
# Processing Record 44 of Set 13 | corralillo
# Processing Record 45 of Set 13 | killybegs
# Processing Record 46 of Set 13 | srikakulam
# Processing Record 47 of Set 13 | puerto rondon
# Processing Record 48 of Set 13 | prince rupert
# Processing Record 49 of Set 13 | pontianak
# Processing Record 50 of Set 13 | port lincoln
# Processing Record 1 of Set 14 | benguela
# Processing Record 2 of Set 14 | thinadhoo
# Processing Record 3 of Set 14 | sinop
# Processing Record 4 of Set 14 | taoudenni
# Processing Record 5 of Set 14 | mamallapuram
# Processing Record 6 of Set 14 | alyangula
# Processing Record 7 of Set 14 | brigantine
# Processing Record 8 of Set 14 | tilichiki
# Processing Record 9 of Set 14 | ishim
# Processing Record 10 of Set 14 | gallup
# Processing Record 11 of Set 14 | pemberton
# Processing Record 12 of Set 14 | phenix city
# Processing Record 13 of Set 14 | taksimo
# Processing Record 14 of Set 14 | nchelenge
# Processing Record 15 of Set 14 | sandeid
# Processing Record 16 of Set 14 | kangaatsiaq
# Processing Record 17 of Set 14 | saint anthony
# Processing Record 18 of Set 14 | tobermory
# Processing Record 19 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 14 | deer lake
# Processing Record 21 of Set 14 | piacabucu
# Processing Record 22 of Set 14 | hollins
# Processing Record 23 of Set 14 | arecibo
# Processing Record 24 of Set 14 | ust-omchug
# Processing Record 25 of Set 14 | mandera
# Processing Record 26 of Set 14 | humboldt
# Processing Record 27 of Set 14 | derzhavinsk
# Processing Record 28 of Set 14 | los llanos de aridane
# Processing Record 29 of Set 14 | rabak
# Processing Record 30 of Set 14 | mount pleasant
# Processing Record 31 of Set 14 | maragogi
# Processing Record 32 of Set 14 | la palma
# Processing Record 33 of Set 14 | salta
# Processing Record 34 of Set 14 | severka
# Processing Record 35 of Set 14 | erenhot
# Processing Record 36 of Set 14 | elizabethtown
# Processing Record 37 of Set 14 | auki
# Processing Record 38 of Set 14 | subiaco
# Processing Record 39 of Set 14 | hukuntsi
# Processing Record 40 of Set 14 | allada
# Processing Record 41 of Set 14 | bilma
# Processing Record 42 of Set 14 | mormugao
# Processing Record 43 of Set 14 | woodward
# Processing Record 44 of Set 14 | manokwari
# Processing Record 45 of Set 14 | ugoofaaru
# Processing Record 46 of Set 14 | bradford
# Processing Record 47 of Set 14 | bourg-en-bresse
# Processing Record 48 of Set 14 | copiapo
# Processing Record 49 of Set 14 | ucluelet
# Processing Record 50 of Set 14 | saint-denis
# Processing Record 1 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 15 | savalou
# Processing Record 3 of Set 15 | opuwo
# Processing Record 4 of Set 15 | jieshi
# Processing Record 5 of Set 15 | nagua
# Processing Record 6 of Set 15 | manbij
# Processing Record 7 of Set 15 | jalu
# Processing Record 8 of Set 15 | luganville
# Processing Record 9 of Set 15 | bolonchen
# City not found. Skipping...
# Processing Record 10 of Set 15 | isabela
# Processing Record 11 of Set 15 | zhigansk
# Processing Record 12 of Set 15 | zhigalovo
# Processing Record 13 of Set 15 | yuanping
# Processing Record 14 of Set 15 | comodoro rivadavia
# Processing Record 15 of Set 15 | kavaratti
# Processing Record 16 of Set 15 | padre bernardo
# Processing Record 17 of Set 15 | tabou
# Processing Record 18 of Set 15 | turayf
# Processing Record 19 of Set 15 | callaway
# Processing Record 20 of Set 15 | grenfell
# Processing Record 21 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 15 | ushibuka
# Processing Record 23 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 15 | plettenberg bay
# Processing Record 25 of Set 15 | kloulklubed
# Processing Record 26 of Set 15 | clyde river
# Processing Record 27 of Set 15 | aswan
# Processing Record 28 of Set 15 | wucheng
# Processing Record 29 of Set 15 | san juan del parana
# Processing Record 30 of Set 15 | zakamensk
# Processing Record 31 of Set 15 | yuci
# Processing Record 32 of Set 15 | gondanglegi
# Processing Record 33 of Set 15 | terrace
# Processing Record 34 of Set 15 | bestobe
# Processing Record 35 of Set 15 | sechura
# Processing Record 36 of Set 15 | stolin
# Processing Record 37 of Set 15 | san francisco
# Processing Record 38 of Set 15 | batagay-alyta
# Processing Record 39 of Set 15 | cienaga
# Processing Record 40 of Set 15 | jibuti
# Processing Record 41 of Set 15 | sindor
# Processing Record 42 of Set 15 | dumas
# Processing Record 43 of Set 15 | soyo
# Processing Record 44 of Set 15 | port hueneme
# Processing Record 45 of Set 15 | abengourou
# Processing Record 46 of Set 15 | havelock
# Processing Record 47 of Set 15 | camana
# Processing Record 48 of Set 15 | xinzhi
# Processing Record 49 of Set 15 | dicabisagan
# Processing Record 50 of Set 15 | veraval
# Processing Record 1 of Set 16 | wanning
# Processing Record 2 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 16 | trairi
# Processing Record 4 of Set 16 | krasnoselkup
# Processing Record 5 of Set 16 | obo
# Processing Record 6 of Set 16 | abong mbang
# Processing Record 7 of Set 16 | uyar
# Processing Record 8 of Set 16 | kieta
# Processing Record 9 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 16 | somerset west
# Processing Record 11 of Set 16 | sortland
# Processing Record 12 of Set 16 | mirnyy
# Processing Record 13 of Set 16 | doha
# Processing Record 14 of Set 16 | gurgan
# City not found. Skipping...
# Processing Record 15 of Set 16 | bardiyah
# Processing Record 16 of Set 16 | lovozero
# Processing Record 17 of Set 16 | taga
# Processing Record 18 of Set 16 | ambilobe
# Processing Record 19 of Set 16 | gwadar
# Processing Record 20 of Set 16 | tinyahuarco
# Processing Record 21 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 16 | chernyshevskiy
# Processing Record 23 of Set 16 | ayan
# Processing Record 24 of Set 16 | ryotsu
# Processing Record 25 of Set 16 | sistranda
# Processing Record 26 of Set 16 | hitoyoshi
# Processing Record 27 of Set 16 | amancio
# City not found. Skipping...
# Processing Record 28 of Set 16 | kirakira
# Processing Record 29 of Set 16 | santa rosa
# Processing Record 30 of Set 16 | gravdal
# Processing Record 31 of Set 16 | baghdad
# Processing Record 32 of Set 16 | tibati
# Processing Record 33 of Set 16 | dujuma
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Total number of cities
print(len(city_data))
# Out:
# 715

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Kijang  35.2442  129.2139     60.80        67          75       10.36
# 1   Kaitangata -46.2817  169.8464     64.00        79         100       11.01
# 2  New Norfolk -42.7826  147.0587     64.00        39          75       10.00
# 3        Kapaa  22.0752 -159.3190     78.80        73          20       14.97
# 4  Novi Ligure  44.7608    8.7896     51.01        83          96        3.40
# 5  Tuktoyaktuk  69.4541 -133.0374    -11.20        77          40        5.75
# 6     Hermanus -34.4187   19.2345     57.00        83          18        3.00
# 7     Bilibino  68.0546  166.4372     -0.22        78           6        2.10
# 8      Redmond  47.6740 -122.1215     54.00        70         100        2.17
# 9        Vaini -21.2000 -175.2000     86.00        74          40        9.22
#
#   Country Current Description                 Date
# 0      KR       broken clouds  2021-03-28 01:40:47
# 1      NZ       moderate rain  2021-03-28 01:40:47
# 2      AU       broken clouds  2021-03-28 01:40:48
# 3      US          few clouds  2021-03-28 01:40:48
# 4      IT     overcast clouds  2021-03-28 01:40:48
# 5      CA    scattered clouds  2021-03-28 01:40:49
# 6      ZA          few clouds  2021-03-28 01:40:49
# 7      RU           clear sky  2021-03-28 01:40:50
# 8      US     overcast clouds  2021-03-28 01:40:50
# 9      TO          light rain  2021-03-28 01:38:19

# %%
#Reorder columns
new_col_order = ["City", "Country", "Date", "Lat", "Lng", 
                 "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_col_order]

# %%
city_data_df
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0         Kijang      KR  2021-03-28 01:40:47  35.2442  129.2139     60.80
# 1     Kaitangata      NZ  2021-03-28 01:40:47 -46.2817  169.8464     64.00
# 2    New Norfolk      AU  2021-03-28 01:40:48 -42.7826  147.0587     64.00
# 3          Kapaa      US  2021-03-28 01:40:48  22.0752 -159.3190     78.80
# 4    Novi Ligure      IT  2021-03-28 01:40:48  44.7608    8.7896     51.01
# ..           ...     ...                  ...      ...       ...       ...
# 710     Kirakira      SB  2021-03-28 01:44:43 -10.4544  161.9205     84.85
# 711   Santa Rosa      PH  2021-03-28 01:44:43  14.3122  121.1114     89.01
# 712      Gravdal      NO  2021-03-28 01:44:43  68.1214   13.5031     36.91
# 713      Baghdad      IQ  2021-03-28 01:44:44  33.3406   44.4009     46.40
# 714       Tibati      CM  2021-03-28 01:44:44   6.4667   12.6333     73.51
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          67          75       10.36       broken clouds
# 1          79         100       11.01       moderate rain
# 2          39          75       10.00       broken clouds
# 3          73          20       14.97          few clouds
# 4          83          96        3.40     overcast clouds
# ..        ...         ...         ...                 ...
# 710        75          41       10.98    scattered clouds
# 711        58          20        5.75          few clouds
# 712        64          87       23.42     overcast clouds
# 713        39           0        9.22           clear sky
# 714        29          91        3.89     overcast clouds
#
# [715 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
